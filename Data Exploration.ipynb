# %% [markdown]
# # Data Exploration: Los Angeles Affordable Housing Projects

# %% [markdown]
# ## Introduction
#
# The California Tax Credit Allocation Committee (TCAC) keeps track of all the multifamily housing projects developed using Low Income Housing Tax Credits (LIHTC) in California. ([Source](https://www.treasurer.ca.gov/ctcac/projects.asp)). From this data set I pulled out the Los Angeles data to begin exploring. I've uploaded it to the data folder but I think we need to import the pandas library first to be able to read it.

# %%
# we import this so we can process this csv file easier.
import pandas as pd

# %% [markdown]
# Now we can import the data into a variable so we can use it later

# %%
# create a variable called projects and fill it with the data from the csv fle.
projects = pd.read_csv('data/LAProjects.csv')

# %% [markdown]
# ## Look at the data
# To get a peek of the data, we can take a look at the "info" of the file to get a preview of what data is in this file

# %%
# give me the overall info about this file
projects.info
# Out:
# <bound method DataFrame.info of      Application Number  Unnamed: 1 Type of tax credit funding  \
# 0           CA-2000-858         NaN                         4%
# 1           CA-2005-863         NaN                         4%
# 2           CA-1992-901         NaN                         4%
# 3           CA-2003-819         NaN                         4%
# 4           CA-2010-830         NaN                         4%
# ...                 ...         ...                        ...
# 1301        CA-2009-856         NaN                         4%
# 1302        CA-2013-825         NaN                         4%
# 1303        CA-1995-009         NaN                         9%
# 1304        CA-2014-876         NaN                         4%
# 1305        CA-2016-875         NaN                         4%
#
#                        Project Name  \
# 0                 Main Street Plaza
# 1         Wysong Village Apartments
# 2        Altadena Vistas Apartments
# 3          Heritage Park at Arcadia
# 4                    Campus Commons
# ...                             ...
# 1301  Dana Strand Senior Apartments
# 1302       Banning Villa Apartments
# 1303              Roscoe Apartments
# 1304     Winnetka Senior Apartments
# 1305    Rancho Del Valle Apartments
#
#                                         Project Address    Project City  \
# 0         333 West Main Street, Alhambra, CA 918017427         Alhambra
# 1      111 North Chapel Avenue, Alhambra, CA 918010000         Alhambra
# 2      815 E. Calaveras Street, Altadena, CA 91001             Altadena
# 3      150 West Las Tunas Drive, Arcadia, CA 91007              Arcadia
# 4               16 Campus Drive, Arcadia, CA 91007              Arcadia
# ...                                                 ...             ...
# 1301     410 Hawaiian Avenue, Wilmington, CA 90744           Wilmington
# 1302  1100 North Banning Boulevard, Wilmington, CA 9...      Wilmington
# 1303        20234 Roscoe Blvd., Winnetka, CA 91306             Winnetka
# 1304             20750 Sherman Way, Winnetka, CA, 91306        Winnetka
# 1305        6560 Winnetka Ave, Woodland Hills, CA 91367  Woodland Hills
#
#      Project Zip Code Project Phone Number Project County  \
# 0               91801         626-289-5800    Los Angeles
# 1               91801         626-284-3956    Los Angeles
# 2               91001         323-734-2111    Los Angeles
# 3               91007         626-821-9048    Los Angeles
# 4               91007         626.445.7017    Los Angeles
# ...               ...                  ...            ...
# 1301            90744         310-518-1200    Los Angeles
# 1302            90744           3105497028    Los Angeles
# 1303            91306         818-882-5131    Los Angeles
# 1304            91306                  NaN    Los Angeles
# 1305            91367                  NaN    Los Angeles
#
#       California Assembly District  ...  Management Company Fax  \
# 0                             49.0  ...            310-432-0888
# 1                             49.0  ...            614-273-2154
# 2                             41.0  ...            310-358-3494
# 3                             49.0  ...              9167730529
# 4                             49.0  ...            559.476.5538
# ...                            ...  ...                     ...
# 1301                          64.0  ...            916-357-5320
# 1302                          64.0  ...              3108026680
# 1303                          45.0  ...            209 370-1574
# 1304                          45.0  ...              2138331866
# 1305                          45.0  ...                     NaN
#
#                                         Developer Annual Federal Award  \
# 0                                             NaN             $486,869
# 1                      National Church Residences             $293,106
# 2           L.A. Community Development Commission              $74,027
# 3                    American Senior Living, Inc.             $295,337
# 4                       Ashwood Construction, Inc             $383,390
# ...                                           ...                  ...
# 1301                 Roem Development Corporation             $950,112
# 1302            Preservation Partners Development             $680,299
# 1303           Century Pacific Equity Corporation             $123,286
# 1304                     Meta Housing Corporation             $947,682
# 1305  BlueGreen Preservation and Development, LLC             $235,133
#
#      Total State Award Unnamed: 62 Unnamed: 63 Unnamed: 64 Unnamed: 65  \
# 0                   $0         NaN         NaN         NaN         NaN
# 1                   $0         NaN         NaN         NaN         NaN
# 2                   $0         NaN         NaN         NaN         NaN
# 3                   $0         NaN         NaN         NaN         NaN
# 4                   $0         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 1301                $0         NaN         NaN         NaN         NaN
# 1302               NaN         NaN         NaN         NaN         NaN
# 1303                $0         NaN         NaN         NaN         NaN
# 1304               NaN         NaN         NaN         NaN         NaN
# 1305               NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 66  Unnamed: 67
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ...          ...          ...
# 1301         NaN          NaN
# 1302         NaN          NaN
# 1303         NaN          NaN
# 1304         NaN          NaN
# 1305         NaN          NaN
#
# [1306 rows x 68 columns]>

# %% [markdown]
# Now let's see what the "shape of it is"

# %%
# show the (rows, columns)
projects.shape
# Out:
# (1306, 68)

# %% [markdown]
# And finally, we can take a peek at the first few rows of data's "head"

# %%
# show me the first 5 rows
projects.head()
# Out:
#   Application Number  Unnamed: 1 Type of tax credit funding  \
# 0        CA-2000-858         NaN                         4%
# 1        CA-2005-863         NaN                         4%
# 2        CA-1992-901         NaN                         4%
# 3        CA-2003-819         NaN                         4%
# 4        CA-2010-830         NaN                         4%
#
#                  Project Name  \
# 0           Main Street Plaza
# 1   Wysong Village Apartments
# 2  Altadena Vistas Apartments
# 3    Heritage Park at Arcadia
# 4              Campus Commons
#
#                                     Project Address Project City  \
# 0     333 West Main Street, Alhambra, CA 918017427      Alhambra
# 1  111 North Chapel Avenue, Alhambra, CA 918010000      Alhambra
# 2  815 E. Calaveras Street, Altadena, CA 91001          Altadena
# 3  150 West Las Tunas Drive, Arcadia, CA 91007           Arcadia
# 4           16 Campus Drive, Arcadia, CA 91007           Arcadia
#
#   Project Zip Code Project Phone Number Project County  \
# 0            91801         626-289-5800    Los Angeles
# 1            91801         626-284-3956    Los Angeles
# 2            91001         323-734-2111    Los Angeles
# 3            91007         626-821-9048    Los Angeles
# 4            91007         626.445.7017    Los Angeles
#
#    California Assembly District  ...  Management Company Fax  \
# 0                          49.0  ...            310-432-0888
# 1                          49.0  ...            614-273-2154
# 2                          41.0  ...            310-358-3494
# 3                          49.0  ...              9167730529
# 4                          49.0  ...            559.476.5538
#
#                                Developer Annual Federal Award  \
# 0                                    NaN             $486,869
# 1             National Church Residences             $293,106
# 2  L.A. Community Development Commission              $74,027
# 3           American Senior Living, Inc.             $295,337
# 4              Ashwood Construction, Inc             $383,390
#
#   Total State Award Unnamed: 62 Unnamed: 63 Unnamed: 64 Unnamed: 65  \
# 0                $0         NaN         NaN         NaN         NaN
# 1                $0         NaN         NaN         NaN         NaN
# 2                $0         NaN         NaN         NaN         NaN
# 3                $0         NaN         NaN         NaN         NaN
# 4                $0         NaN         NaN         NaN         NaN
#
#   Unnamed: 66  Unnamed: 67
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 68 columns]

# %% [markdown]
# # Data Exploration
# Now, let's try to explore this data a little bit.

# %%
# Just show me the columns
projects.columns.to_list()
# Out:
# ['Application Number',
#  'Unnamed: 1',
#  'Type of tax credit funding',
#  'Project Name',
#  'Project Address',
#  'Project City',
#  'Project Zip Code',
#  'Project Phone Number',
#  'Project County',
#  'California Assembly District',
#  'California Senate District',
#  'Federal Congressional District',
#  'Census Tract',
#  "Assessor's Parcel Number (APN)",
#  'Application Stage',
#  'Placed in Service (PIS) Date ',
#  'Last Building PIS Date',
#  'Construction Type',
#  'Housing Type',
#  'Total Units',
#  'Low Income Units',
#  'Number of SRO/Studio Units',
#  'Number of 1 Bedroom Units',
#  'Number of 2 Bedroom Units',
#  'Number of 3 Bedroom Units',
#  'Number of 4 Bedroom Units',
#  'Number of 5 Bedroom Units',
#  'Number of 6 Bedroom Units',
#  'Units at or below 20% AMI',
#  'Units at or below 30% AMI',
#  'Units at 35% AMI',
#  'Units at 40% AMI',
#  'Units at 45% AMI',
#  'Units at 50% AMI',
#  'Units at 55% AMI',
#  'Units at 60% AMI',
#  'Units at 70% AMI',
#  'Units at 80% AMI',
#  'Owner or Applicant Name',
#  'Owner/Applicant Contact',
#  'Owner/Applicant Address',
#  'Owner/Applicant City',
#  'Owner/Applicant State',
#  'Owner/Applicant Zip',
#  'Owner/Applicant Phone',
#  'Owner/Applicant Fax',
#  'General Partner (1)',
#  'General Partner (2)',
#  'General Partner (3)',
#  'General Partner (4)',
#  'General Partner (5)',
#  'Management Company',
#  'Management Company Contact',
#  'Management Company Address',
#  'Management Company City',
#  'Management Company State',
#  'Management Company Zip',
#  'Management Company Phone',
#  'Management Company Fax',
#  'Developer',
#  'Annual Federal Award',
#  'Total State Award',
#  'Unnamed: 62',
#  'Unnamed: 63',
#  'Unnamed: 64',
#  'Unnamed: 65',
#  'Unnamed: 66',
#  'Unnamed: 67']

# %% [markdown]
# Lets start taking a look at what we have in here.

# %%
projects['Project City'].value_counts()
# Out:
# Los Angeles       806
# Long Beach         48
# Santa Monica       37
# Lancaster          25
# Pasadena           19
#                  ...
# Woodland Hills      1
# Santa Clarita       1
# Sunland             1
# Highland Park       1
# Marina Del Rey      1
# Name: Project City, Length: 100, dtype: int64

# %% [markdown]
# Ok, this is a pretty big file. Maybe we should trim down the data to something easier to manage. And then take a look at the new set.

# %%
# create a new variable to store a subset of the columns from the original data set.
projects_trimmed = projects[['Type of tax credit funding',
 'Project Name',
 'Project Address',
 'Project City',
 'Project Zip Code',
 'Project County',
 'Census Tract',
 'Construction Type',
 'Housing Type',
 'Total Units',
 'Low Income Units',
 'Owner or Applicant Name',
 'Developer',
 'Annual Federal Award',
 'Total State Award',
]]
# show a preview of the first 5 rows.
projects_trimmed.head()
# Out:
#   Type of tax credit funding                Project Name  \
# 0                         4%           Main Street Plaza
# 1                         4%   Wysong Village Apartments
# 2                         4%  Altadena Vistas Apartments
# 3                         4%    Heritage Park at Arcadia
# 4                         4%              Campus Commons
#
#                                     Project Address Project City  \
# 0     333 West Main Street, Alhambra, CA 918017427      Alhambra
# 1  111 North Chapel Avenue, Alhambra, CA 918010000      Alhambra
# 2  815 E. Calaveras Street, Altadena, CA 91001          Altadena
# 3  150 West Las Tunas Drive, Arcadia, CA 91007           Arcadia
# 4           16 Campus Drive, Arcadia, CA 91007           Arcadia
#
#   Project Zip Code Project County Census Tract  Construction Type  \
# 0            91801    Los Angeles      4803.04   New Construction
# 1            91801    Los Angeles      4810.02  Acquisition/Rehab
# 2            91001    Los Angeles         4611   New Construction
# 3            91007    Los Angeles         4316   New Construction
# 4            91007    Los Angeles      4307.21   New Construction
#
#   Housing Type  Total Units  Low Income Units  \
# 0       Senior        110.0             109.0
# 1       Senior         95.0              94.0
# 2       Senior         22.0              22.0
# 3       Senior         54.0              53.0
# 4       Senior         43.0              42.0
#
#                       Owner or Applicant Name  \
# 0              Main Street Plaza/4th St. L.P.
# 1                Wysong Village Apartments LP
# 2     Altadena Vistas Apartments Limited Part
# 3        Arcadia Heritage Park, L.P., a CA LP
# 4  Arcadia Campus Commons Associates, a CA LP
#
#                                Developer Annual Federal Award  \
# 0                                    NaN             $486,869
# 1             National Church Residences             $293,106
# 2  L.A. Community Development Commission              $74,027
# 3           American Senior Living, Inc.             $295,337
# 4              Ashwood Construction, Inc             $383,390
#
#   Total State Award
# 0                $0
# 1                $0
# 2                $0
# 3                $0
# 4                $0

# %% [markdown]
# Let's start doing some summaries of the data. How many 9% vs 4% projects are there?

# %%
# Count the number of projects for each type of tax credit funding.
projects['Type of tax credit funding'].value_counts()
# Out:
# 9%         606
# 4%         489
# 9% ARRA     16
# 4% ARRA      9
# Name: Type of tax credit funding, dtype: int64

# %% [markdown]
# I'm not sure what these ARRA ones are all about but let's move on to Construction Type.

# %%
# Count the number of projects for each type of construction.
projects['Construction Type'].value_counts()
# Out:
# New Construction                                     689
# Acquisition/Rehab                                    218
# Acquisition/Rehabilitation                           181
# Rehabilitation                                       109
# Acquisition & Rehabilitation                          26
# New Construction                                      19
# Acquisition and Rehabilitation                         3
# New Construction and Acquisition & Rehabilitation      2
# New Construction / Adaptive Reuse                      1
# Name: Construction Type, dtype: int64

# %% [markdown]
# Uhg this column is a mess, and needs to be cleaned up because people are sloppy with their data input. But I don't know how to do that yet so I will just move on for now. What about the type of housing?

# %%
# Count the number of projects for each type of housing.
projects['Housing Type'].value_counts()
# Out:
# Large Family                  502
# Senior                        184
# Special Needs                 178
# Non Targeted                  130
# Non-Targeted                  109
# Seniors                        68
# At-Risk                        67
# SRO                            63
# Special Needs/SRO               2
# New Construction                1
# Special Needs/Large Family      1
# non-targeted                    1
# Name: Housing Type, dtype: int64

# %% [markdown]
# This one looks a little better but also needs to have some of the things merged and cleaned up, there's a lot of duplicates. At the very least, Large Family seems to be a mostly consistent category so let's look at that one in particular. (I tried several different ways to trim it but this was the only one that worked because my column name has a space in it i think.)

# %%
# Create a new variable to store only the large family housing type projects. 
LF_Fam = projects_trimmed.loc[projects['Housing Type'] == 'Large Family']

# Show the new table
LF_Fam
# Out:
#      Type of tax credit funding                               Project Name  \
# 7                            9%                            Cantamar Villas
# 10                           4%                               Villa Ramona
# 11                           9%     Baldwin Park Transit Center Apartments
# 12                           9%                           Villa Florentina
# 23                           9%                              Alabama Court
# ...                         ...                                        ...
# 1292                         9%                           Sunshine Terrace
# 1295                         9%                 Mosaic Gardens at Whittier
# 1299                         9%  New Dana Strand Phase 1 Garden Apartments
# 1300                         4%                 New Dana Strand Town Homes
# 1303                         9%                          Roscoe Apartments
#
#                                         Project Address  Project City  \
# 7              309 Beacon Street, Avalon, CA 90704             Avalon
# 10      13030 Ramona Blvd., Baldwin Park, CA 91706       Baldwin Park
# 11    Ramona Boulevard and Maine Avenue, Baldwin Par...  Baldwin Park
# 12            4576 Florence Avenue, Bell, CA 90201               Bell
# 23      7440 Alabama Avenue, Canoga Park, CA 91303        Canoga Park
# ...                                                 ...           ...
# 1292       10800 Laurel Avenue, Whittier, CA 90605           Whittier
# 1295  12524 Philadelphia Street, Whittier, CA 90602 ...      Whittier
# 1299      326 N. King Avenue, Wilmington, CA 90744         Wilmington
# 1300      450 N. King Avenue, Wilmington, CA 907440000     Wilmington
# 1303        20234 Roscoe Blvd., Winnetka, CA 91306           Winnetka
#
#      Project Zip Code Project County Census Tract Construction Type  \
# 7               90704    Los Angeles         5990  New Construction
# 10              91706    Los Angeles      4048.01  New Construction
# 11              91706    Los Angeles          NaN  New Construction
# 12              90201    Los Angeles      5338.03  New Construction
# 23              91303    Los Angeles      1345.22               NaN
# ...               ...            ...          ...               ...
# 1292            90605    Los Angeles      5029.02  New Construction
# 1295            90601    Los Angeles         5014  New Construction
# 1299            90744    Los Angeles         2949  New Construction
# 1300            90744    Los Angeles         2949  New Construction
# 1303            91306    Los Angeles      1134.22               NaN
#
#       Housing Type  Total Units  Low Income Units  \
# 7     Large Family         38.0              36.0
# 10    Large Family         71.0              70.0
# 11    Large Family         70.0              69.0
# 12    Large Family         13.0              12.0
# 23    Large Family         43.0              42.0
# ...            ...          ...               ...
# 1292  Large Family         50.0              49.0
# 1295  Large Family         21.0              20.0
# 1299  Large Family        120.0             118.0
# 1300  Large Family        116.0             114.0
# 1303  Large Family         25.0              24.0
#
#                                 Owner or Applicant Name  \
# 7              Catalina Avalon Limited, a California LP
# 10    Baldwin Park Family Housing Limited Partnershi...
# 11                         ROEM Development Corporation
# 12                                Villa Florentina, LLC
# 23                                    Alabama Court, LP
# ...                                                 ...
# 1292    Sunshine Terrace Apartments Limited Partnership
# 1295                   Whittier Family Apartments, L.P.
# 1299                   New Dana Strand Partners I, L.P.
# 1300                New Dana Strand Town Homes, a CA LP
# 1303                              20234 Roscoe Blvd. LP
#
#                                Developer Annual Federal Award  \
# 7                                    NaN             $232,245
# 10            Thomas Safran & Associates             $522,176
# 11          ROEM Development Corporation           $1,522,725
# 12              MICH Development Company             $153,218
# 23               LA Family Housing Corp.             $367,104
# ...                                  ...                  ...
# 1292                   Abode Communities             $667,938
# 1295            LINC Housing Corporation             $413,565
# 1299                   Abode Communities           $1,629,992
# 1300            Mercy Housing California           $1,739,269
# 1303  Century Pacific Equity Corporation             $123,286
#
#      Total State Award
# 7                   $0
# 10                  $0
# 11                  $0
# 12                  $0
# 23                  $0
# ...                ...
# 1292                $0
# 1295                $0
# 1299        $6,145,706
# 1300                $0
# 1303                $0
#
# [502 rows x 15 columns]

# %% [markdown]
# ## Foucus in on one particular developer
#
# So this is starting to look a little interesting.

# %%
# Count the number of projects by developer
LF_Fam['Developer'].value_counts()
# Out:
# Abode Communities                        22
# Meta Housing Corporation                 20
# Community Corporation of Santa Monica    19
# AMCAL Enterprises, Inc.                  11
# American Communities, LLC                 9
#                                          ..
# Arlington-Rodeo Properties Inc.           1
# Spruce Dev LA, LLC                        1
# ABS Properties, Inc.                      1
# Decro Corp. / Veloce Partners             1
# Esperanza Community Housing Corp.         1
# Name: Developer, Length: 219, dtype: int64

# %% [markdown]
# Now we have our top 5 developers of Large Family affordable housing bubbled up to the top here! I would like to have it show more than the top 5, maybe top 10 would be nice but I'm not sure how to do it.

# %%
# Create a new variable with just the Adobe Communitities projects
topdev_trimmed = LF_Fam.loc[LF_Fam['Developer'] == 'Abode Communities']
topdev_trimmed
# Out:
#      Type of tax credit funding                                  Project Name  \
# 80                           9%                                Casa Dominguez
# 188                          9%                              Osage Apartments
# 196                          4%                     Grisham Community Housing
# 275                          9%                               Villa Esperanza
# 319                          9%                         Park Place Apartments
# 338                          9%                                  Oxnard Villa
# 339                          9%                               Parthenia Court
# 340                          9%                                Reseda Village
# 355                          9%                       Astoria Place Townhomes
# 575                          9%                                  Hart Village
# 698                          4%                                   Ivy Terrace
# 707                          9%               Glassell Park Community Housing
# 796                          9%                           Riverwalk at Reseda
# 840                          9%                       Selma Community Housing
# 890                          9%                           Rolland Curtis East
# 902                          4%                                 Vista Del Mar
# 945                          4%                           Rolland Curtis West
# 946                          4%                                New Park Place
# 1111                         9%                    Villa Parke Homes (Site A)
# 1244                         4%  Viviendas del Valle - (Astoria Place Site A)
# 1292                         9%                              Sunshine Terrace
# 1299                         9%     New Dana Strand Phase 1 Garden Apartments
#
#                                         Project Address  \
# 80    15729 S. Atlantic Avenue, East Rancho Domingue...
# 188           11128 Osage Avenue, Lennox, CA 90304
# 196            4901 Ruth Ave., Long Beach, CA 908050000
# 275    255 East 28th Street, Los Angeles, CA 90011
# 319    2500 West 4th Street, Los Angeles, CA 90057
# 338     14045 Oxnard Street, Los Angeles, CA 91401
# 339   14825 Parthenia Street, Los Angeles, CA 91402 ...
# 340   7939 Reseda Boulevard, Los Angeles, CA 91335
# 355    13230 Bromont Avenue, Los Angeles, CA 91342
# 575   6941 Owensmouth Avenue, Los Angeles, CA 91303-...
# 698       13751 Sherman Way, Los Angeles, CA 91405
# 707       3000 Verdugo Road, Los Angeles, CA 70065
# 796    18425 W. Kittridge Street, Los Angeles, CA 91335
# 840     1603 N. Cherokee Avenue, Los Angeles, CA, 90028
# 890              1077 W 38th St., Los Angeles, CA 90037
# 902           1116 West D Street, Los Angeles, CA 90744
# 945           1077 W 38th Street, Los Angeles, CA 90037
# 946            2500 W 4th Street, Los Angeles, CA 90057
# 1111         422 North Raymond Ave., Pasadena, CA 90001
# 1244                 13230 Bromont St, Sylmar, CA 91342
# 1292       10800 Laurel Avenue, Whittier, CA 90605
# 1299      326 N. King Avenue, Wilmington, CA 90744
#
#                Project City Project Zip Code Project County Census Tract  \
# 80    East Rancho Dominguez            90221    Los Angeles      5421.06
# 188                  Lennox            90304    Los Angeles         6017
# 196              Long Beach            90805    Los Angeles      5717.01
# 275             Los Angeles            90011    Los Angeles         2246
# 319             Los Angeles            90057    Los Angeles      2088.02
# 338             Los Angeles            91401    Los Angeles      1286.01
# 339             Los Angeles            91402    Los Angeles      1201.08
# 340             Los Angeles            91335    Los Angeles      1310.10
# 355             Los Angeles            91342    Los Angeles      1064.07
# 575             Los Angeles            91303    Los Angeles      1345.20
# 698             Los Angeles            91405    Los Angeles      1279.20
# 707             Los Angeles            70065    Los Angeles      1864.04
# 796             Los Angeles            91335    Los Angeles         1327
# 840             Los Angeles            90028    Los Angeles      1907.00
# 890             Los Angeles            90037    Los Angeles      2312.20
# 902             Los Angeles            90744    Los Angeles      2949.00
# 945             Los Angeles            90037    Los Angeles      2312.20
# 946             Los Angeles            90057    Los Angeles      2088.02
# 1111               Pasadena            90001    Los Angeles      4619.02
# 1244                 Sylmar            91342    Los Angeles      1064.07
# 1292               Whittier            90605    Los Angeles      5029.02
# 1299             Wilmington            90744    Los Angeles         2949
#
#                Construction Type  Housing Type  Total Units  Low Income Units  \
# 80              New Construction  Large Family         70.0              69.0
# 188             New Construction  Large Family         21.0              21.0
# 196            Acquisition/Rehab  Large Family         96.0              94.0
# 275             New Construction  Large Family         33.0              33.0
# 319             New Construction  Large Family         49.0              49.0
# 338                          NaN  Large Family         40.0              39.0
# 339             New Construction  Large Family         25.0              24.0
# 340                          NaN  Large Family         42.0              41.0
# 355             New Construction  Large Family         18.0              17.0
# 575             New Construction  Large Family         47.0              46.0
# 698             New Construction  Large Family         52.0              51.0
# 707             New Construction  Large Family         50.0              49.0
# 796             New Construction  Large Family         77.0              76.0
# 840             New Construction  Large Family         66.0              65.0
# 890             New Construction  Large Family         70.0              69.0
# 902             New Construction  Large Family         88.0              87.0
# 945             New Construction  Large Family         70.0              69.0
# 946   Acquisition/Rehabilitation  Large Family         49.0              48.0
# 1111                         NaN  Large Family          9.0               9.0
# 1244  Acquisition/Rehabilitation  Large Family        100.0              97.0
# 1292            New Construction  Large Family         50.0              49.0
# 1299            New Construction  Large Family        120.0             118.0
#
#                                 Owner or Applicant Name          Developer  \
# 80                                 Casa Dominguez, L.P.  Abode Communities
# 188                Osage Apartments Limited Partnership  Abode Communities
# 196       Grisham Community Housing Limited Partnership  Abode Communities
# 275                 Villa Esperanza Limited Partnership  Abode Communities
# 319                           Park Place Apartments, LP  Abode Communities
# 338                    Oxnard Villa Limited Partnership  Abode Communities
# 339   Parthenia Housing Associates, Limited Partnership  Abode Communities
# 340                                  Reseda Village, LP  Abode Communities
# 355                   Astoria Place Limited Partnership  Abode Communities
# 575                                    Hart Village, LP  Abode Communities
# 698                 Sherman Way Community Housing, L.P.  Abode Communities
# 707                                    Glassell Park LP  Abode Communities
# 796                             Kittridge Housing, L.P.  Abode Communities
# 840                       Selma Community Housing, L.P.  Abode Communities
# 890                           Rolland Curtis East, L.P.  Abode Communities
# 902                          New Dana Strand IV-B, L.P.  Abode Communities
# 945                           Rolland Curtis West, L.P.  Abode Communities
# 946                                New Park Place, L.P.  Abode Communities
# 1111                    Villa Parke Limited Partnership  Abode Communities
# 1244                          Viviendas del Valle, L.P.  Abode Communities
# 1292    Sunshine Terrace Apartments Limited Partnership  Abode Communities
# 1299                   New Dana Strand Partners I, L.P.  Abode Communities
#
#      Annual Federal Award Total State Award
# 80             $1,754,750                $0
# 188              $199,121                $0
# 196              $607,458                $0
# 275              $605,423                $0
# 319              $897,493                $0
# 338              $243,064                $0
# 339              $333,921                $0
# 340              $327,928                $0
# 355              $164,167                $0
# 575            $1,106,574                $0
# 698              $895,103                $0
# 707            $1,626,341                $0
# 796            $1,338,577               NaN
# 840            $1,892,212                $0
# 890            $2,004,992               NaN
# 902            $1,153,462               NaN
# 945            $1,072,019               NaN
# 946              $353,325               NaN
# 1111              $89,309          $300,708
# 1244             $728,017               NaN
# 1292             $667,938                $0
# 1299           $1,629,992        $6,145,706

# %% [markdown]
# And finally we find out how many of their projects use 9% vs 4% funding

# %%
topdev_trimmed['Type of tax credit funding'].value_counts()
# Out:
# 9%    16
# 4%     6
# Name: Type of tax credit funding, dtype: int64

# %% [markdown]
# I would like to make some graphs or plot these projects on a map but I don't know how to do it with the data I have yet. I imagine there is a way to plot it with the address or census tract but I'm not sure so we'll leave it like this for now.
